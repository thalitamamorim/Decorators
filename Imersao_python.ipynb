# %% [markdown]
# <a href="https://colab.research.google.com/github/thalitamamorim/Decorators/blob/main/Imersao_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/Analise de dados.xlsx", sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
# ...

# %%
df_analises = pd.read_excel("/content/Analise de dados.xlsx", sheet_name="Analises")
df_analises
# Out:
#                        Maior    4762926995.24809                    Vale
# 0                      Menor  -1807432634.459543                Localiza
# 1                      Média     165190210.47934                     NaN
# 2        Média de quem subiu    448164250.230498                     NaN
# 3       Média de quem desceu   -171319458.413928                     NaN
# 4                        NaN                 NaN                     NaN
# 5                        NaN                 NaN                     NaN
# 6                   Segmento            Variação  Variação de quem subiu
# 7                 Siderurgia    489935930.928323        489935930.928323
# 8                  Mineração   4940442965.550434       4940442965.550434
# 9                    Energia     6072848902.7105       6914405231.874114
# 10          Papel e Celulose    722946282.709038        722946282.709038
# 11          Shopping Centers    117732680.078425        117732680.078425
# ...

# %%
df_Total_de_acoes = pd.read_excel("/content/Analise de dados.xlsx", sheet_name="Total_de_acoes")
df_Total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_Ticker = pd.read_excel("/content/Analise de dados.xlsx", sheet_name="Ticker")
df_Ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
df_ChatGTP = pd.read_excel("/content/Analise de dados.xlsx", sheet_name="ChatGTP")
df_ChatGTP
# Out:
#              Empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            64
# 1      CSN Mineração          Mineração            80
# 2          Petrobras            Energia            69
# 3             Suzano   Papel e Celulose            99
# 4       CPFL Energia            Energia           108
# ..               ...                ...           ...
# 75  Carrefour Brasil             Varejo            46
# 76       Casas Bahia             Varejo            99
# 77          Localiza  Aluguel de Carros            48
# 78               CVC            Turismo            49
# 79               GOL   Transporte Aéreo            20
#
# [80 rows x 3 columns]

# %%
resultado = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
resultado
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]
